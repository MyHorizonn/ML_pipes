# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D
from matplotlib.pyplot import gcf, figure
import pandas as pd
import seaborn as sns
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_curve, auc
import mglearn
# %matplotlib inline

#путь к файлу
data = pd.read_csv(r'/home/nikita/ML/pipes/ML_pipes/info/Informatsia.csv')
#data = pd.read_csv(r'H:/Machine_learning/info/Informatsia.csv')

pipes = pd.DataFrame(data)

pipes_for_lin_reg = pipes.head(1200).tail(300).append(pipes.tail(1200).head(300))

pipes = pipes.head(1200).append(pipes.tail(1200))

map_to_int = {name: n for n, name in enumerate(pipes["Вид прокладки тепловой сети"].unique())}
pipes["Вид прокладки тепловой сети"] = pipes["Вид прокладки тепловой сети"].replace(map_to_int)
pipes_for_lin_reg["Вид прокладки тепловой сети"] = pipes_for_lin_reg["Вид прокладки тепловой сети"].replace(map_to_int)
def encode_target(pipes, target_column):
    pipes_mod = pipes.copy()
    targets = pipes[target_column].unique()
    map_to_int = {name: n for n, name in enumerate(targets)}
    pipes_mod["Target"] = pipes_mod[target_column].replace(map_to_int)
    
    return(pipes_mod, targets)

# %%
del pipes['Unnamed: 25']
del pipes['Unnamed: 26']
del pipes['Unnamed: 27']
del pipes_for_lin_reg['Unnamed: 25']
del pipes_for_lin_reg['Unnamed: 26']
del pipes_for_lin_reg['Unnamed: 27']

# %%
pipes2, targets = encode_target(pipes, "Аварийность")
pipes_for_lin_reg2, targets2 = encode_target(pipes_for_lin_reg, "Аварийность")

for i in range(len(pipes.columns)):
   print(i, ":", pipes.columns[i])
# Out:
# 0 : Sys
# 1 : Номер источника
# 2 : Наименование начала участка
# 3 : Наименование конца участка
# 4 : Балансодержатель
# 5 : Длина участка, м
# 6 : Внутpенний диаметp подающего тpубопpовода, м
# 7 : Внутренний диаметр обратного трубопровода, м
# 8 : Диаметр условный ПТ, мм
# 9 : Диаметр условный ОТ, мм
# 10 : Шероховатость подающего трубопровода, мм
# 11 : Шероховатость обратного трубопровода, мм
# 12 : Год ввода в эксплуатацию
# 13 : Вид прокладки тепловой сети
# 14 : Коэффициент местного сопротивления под.тр-да
# 15 : Коэффициент местного сопротивления обр.тр-да
# 16 : Зарастание подающего трубопровода, мм
# 17 : Зарастание обратного трубопровода, мм
# 18 : Расход воды в подающем трубопроводе, т/ч
# 19 : Расход воды в обратном трубопроводе, т/ч
# 20 : Потери напора в подающем трубопроводе, м
# 21 : Потери напора в обратном трубопроводе, м
# 22 : Удельные линейные потери напора в под.тр-де, мм/м
# 23 : Удельные линейные потери напора в обр.тр-де, мм/м
# 24 : Аварийность

# %%
disblance = pipes['Аварийность'].value_counts()
print(disblance[1]/disblance[0])
# Out:
# 1.0

# %%
"""
Надземная = 0
Подземная канальная = 1
Подземная бесканальная = 2
Подвальная = 3
"""

"""
Таргеты:

Без аварии - 0
Авария - 1


"""

#print(pipes2.info())

clmns = list(pipes2.columns[5:24])
#print(pipes2.info())

cr = clmns + list(pipes2.columns[24:25])

for i in range(len(cr)):
   print(i, ":", cr[i])
# Out:
# 0 : Длина участка, м
# 1 : Внутpенний диаметp подающего тpубопpовода, м
# 2 : Внутренний диаметр обратного трубопровода, м
# 3 : Диаметр условный ПТ, мм
# 4 : Диаметр условный ОТ, мм
# 5 : Шероховатость подающего трубопровода, мм
# 6 : Шероховатость обратного трубопровода, мм
# 7 : Год ввода в эксплуатацию
# 8 : Вид прокладки тепловой сети
# 9 : Коэффициент местного сопротивления под.тр-да
# 10 : Коэффициент местного сопротивления обр.тр-да
# 11 : Зарастание подающего трубопровода, мм
# 12 : Зарастание обратного трубопровода, мм
# 13 : Расход воды в подающем трубопроводе, т/ч
# 14 : Расход воды в обратном трубопроводе, т/ч
# 15 : Потери напора в подающем трубопроводе, м
# 16 : Потери напора в обратном трубопроводе, м
# 17 : Удельные линейные потери напора в под.тр-де, мм/м
# 18 : Удельные линейные потери напора в обр.тр-де, мм/м
# 19 : Аварийность

# %%
sns.heatmap(pipes.corr('kendall'), cmap="seismic", vmin=-1, vmax=1) ;

# %%
corr = pipes[cr].corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col0,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col1,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col2,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow2_col1,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow2_col2,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow3_col3,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow3_col4,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow4_col3,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow4_col4,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow5_col5,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow6_col6,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow7_col7,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow8_col8,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow9_col9,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow10_col10,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow11_col11,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow12_col12,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow13_col13,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow14_col14,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow15_col15,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow16_col16,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow17_col17,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow18_col18,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow19_col19{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col1,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col2,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow7_col13{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col3,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col4{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col5{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col6,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow8_col19{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col7{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col8{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col9,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow2_col6{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col10,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow8_col17,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow16_col11{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col11,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow3_col14,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow4_col14,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow10_col8,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow17_col8,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow18_col8{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col12{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col13{
#             background-color:  #eed0c0;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col14,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow2_col12,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow5_col1,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow6_col4,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow10_col19{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col15,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow6_col2,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow7_col12{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col16,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow12_col7,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow13_col9,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow17_col1,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow17_col2,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow19_col7{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col17,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col18,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow9_col0,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow19_col8,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow19_col15{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow0_col19,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col6,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow8_col3,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow8_col4{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col0,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow2_col0,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow11_col4{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col3,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow3_col1{
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col4,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow2_col3,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow2_col4,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow3_col2,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow4_col1,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow4_col2,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow5_col6,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow6_col5,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow17_col18,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow18_col17{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col5,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow8_col9,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow14_col9{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col7,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col9,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow2_col7,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow3_col5,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow4_col7,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow17_col4,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow17_col9,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow17_col16{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col8,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow2_col8,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow3_col8,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow4_col8,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow5_col16,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow5_col19,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow6_col7,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow6_col11,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow6_col15,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow6_col17,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow6_col18,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow7_col10,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow9_col12,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow9_col16,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow12_col9,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow13_col14,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow14_col0,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow14_col1,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow14_col2,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow14_col3,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow14_col4,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow14_col13,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow19_col5,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow19_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow1_col10,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow2_col10,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow8_col10,#T_9b51ef94_b253_11eb_9d64_f5c093a10faerow16

# %%
new_clmns = list(clmns[1:15])
for i in new_clmns: print(i)
cr = new_clmns + list(pipes2.columns[24:25])
corr = pipes[cr].corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# Внутpенний диаметp подающего тpубопpовода, м
# Внутренний диаметр обратного трубопровода, м
# Диаметр условный ПТ, мм
# Диаметр условный ОТ, мм
# Шероховатость подающего трубопровода, мм
# Шероховатость обратного трубопровода, мм
# Год ввода в эксплуатацию
# Вид прокладки тепловой сети
# Коэффициент местного сопротивления под.тр-да
# Коэффициент местного сопротивления обр.тр-да
# Зарастание подающего трубопровода, мм
# Зарастание обратного трубопровода, мм
# Расход воды в подающем трубопроводе, т/ч
# Расход воды в обратном трубопроводе, т/ч
# <style  type="text/css" >
# #T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col0,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col1,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col0,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col1,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col2,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col3,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col2,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col3,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow4_col4,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow5_col5,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow6_col6,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow7_col7,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow8_col8,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow9_col9,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow10_col10,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow11_col11,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow12_col12,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow13_col13,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col2,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col0{
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col3,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col2,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col3,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col1,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col0,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col1,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow4_col5,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow5_col4{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col4,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow7_col8,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow13_col8{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col5,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow7_col2,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow7_col3{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col6,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col8,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col6,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col4,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col6{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col7,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col7,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col7,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col7,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow4_col14,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow5_col6,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow5_col10,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow6_col9,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow8_col11,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow11_col8,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow12_col13,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow13_col0,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow13_col1,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow13_col2,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow13_col3,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow13_col12,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow14_col4,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow14_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col9,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col9,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow7_col9{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col10,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col10,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow10_col4{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col11,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col11,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow4_col1,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow8_col2{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col12,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col12{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col13,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col13,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow13_col10{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow0_col14{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col4{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col5{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col8,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow14_col11{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col10{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col11,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow4_col0,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow5_col3,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow9_col14{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow1_col14,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow12_col11{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col5,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow10_col8{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col6,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col4{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col8,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow12_col4,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow12_col14{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col9,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col9,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow13_col7{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col11,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow6_col13{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col12,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col12{
#             background-color:  #e9785d;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col13,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col13,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow9_col7{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow2_col14{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col5,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow7_col6,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow7_col11,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow10_col6,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow11_col14{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col8,#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow6_col14{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col10{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_9b51ef95_b253_11eb_9d64_f5c093a10faerow3_col14{
#             background-color:  #b7cff9;

# %%
X, y = pipes[new_clmns], pipes2['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
sns.violinplot(x='Аварийность', y='Год ввода в эксплуатацию', data=pipes);

# %%
pipes['Год ввода в эксплуатацию'].hist();

# %%
sns.violinplot(x='Аварийность', y='Шероховатость подающего трубопровода, мм', data=pipes);

# %%
ct = pd.crosstab(pipes['Шероховатость подающего трубопровода, мм'], pipes['Аварийность'])
ct.plot.bar();

# %%
ct = pd.crosstab(pipes['Год ввода в эксплуатацию'], pipes['Аварийность'])
ct.plot.bar();

# %%
dt = tree.DecisionTreeClassifier(min_samples_split=450)
dt.fit(X, y)
figure(num=None, figsize=(22, 10), dpi=80, facecolor='w', edgecolor='k')
#feature_names=clmns для вывода названий таблиц
tree.plot_tree(dt, filled=True, fontsize=10, rounded=True, max_depth=6)
for i in range(len(clmns)):
   print(i, ":", clmns[i])
plt.show()
# Out:
# 0 : Длина участка, м
# 1 : Внутpенний диаметp подающего тpубопpовода, м
# 2 : Внутренний диаметр обратного трубопровода, м
# 3 : Диаметр условный ПТ, мм
# 4 : Диаметр условный ОТ, мм
# 5 : Шероховатость подающего трубопровода, мм
# 6 : Шероховатость обратного трубопровода, мм
# 7 : Год ввода в эксплуатацию
# 8 : Вид прокладки тепловой сети
# 9 : Коэффициент местного сопротивления под.тр-да
# 10 : Коэффициент местного сопротивления обр.тр-да
# 11 : Зарастание подающего трубопровода, мм
# 12 : Зарастание обратного трубопровода, мм
# 13 : Расход воды в подающем трубопроводе, т/ч
# 14 : Расход воды в обратном трубопроводе, т/ч
# 15 : Потери напора в подающем трубопроводе, м
# 16 : Потери напора в обратном трубопроводе, м
# 17 : Удельные линейные потери напора в под.тр-де, мм/м
# 18 : Удельные линейные потери напора в обр.тр-де, мм/м

# %%
#предугадывание шанса аварии
#print(dt.predict_proba([[0.5, 0.5, 2020]])[0])
print("Оценка на обучающем наборе данных: ", dt.score(X, y))
print("Оценка на тестовом наборе данных: ", dt.score(X_test, y_test))
# Out:
# Оценка на обучающем наборе данных:  0.8675
# Оценка на тестовом наборе данных:  0.865

# %%
lr = Ridge().fit(X, y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [ 1.14138406e-01 -2.91203971e-02  2.23869166e-03 -2.01593609e-03
#  -2.87453854e-01  1.66785635e-01 -7.75664883e-04 -2.30967037e-02
#   3.57726648e-01  9.59650828e-01 -1.90410454e-02 -7.21154040e-03
#   4.89264980e-03  4.91713609e-03]
# 0.7577538243556661

# %%
print(X_test.shape, y_test.shape)
# Out:
# (600, 14) (600,)

# %%
print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test))
# Out:
# 0.23862264982357762
# 0.26403548896355244

# %%
max_features = list(range(1, X.shape[1]))
train_results = []
test_results = []
for max_feature in max_features:
    model = GradientBoostingClassifier(max_features=max_feature)
    model.fit(X, y)
    train_pred = model.predict(X_train)
    fp_rate, tp_rate, threshold = roc_curve(y_train, train_pred)
    roc_auc = auc(fp_rate, tp_rate)
    train_results.append(roc_auc)
    y_pred = model.predict(X_test)
    fp_rate, tp_rate, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(fp_rate, tp_rate)
    test_results.append(roc_auc)

line1, = plt.plot(max_features, train_results, 'b', label='Train AUC')
line2, = plt.plot(max_features, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1:HandlerLine2D(numpoints=2)})

plt.ylabel('AUC score')
plt.xlabel('max features')
plt.show()

# %%
max_depths = list(range(1, 10))
train_results = []
test_results = []
for max_depth in max_depths:
    model = GradientBoostingClassifier(max_depth=max_depth)
    model.fit(X, y)
    train_pred = model.predict(X_train)
    fp_rate, tp_rate, threshold = roc_curve(y_train, train_pred)
    roc_auc = auc(fp_rate, tp_rate)
    train_results.append(roc_auc)
    
    y_pred = model.predict(X_test)
    fp_rate, tp_rate, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(fp_rate, tp_rate)
    test_results.append(roc_auc)

line1, = plt.plot(max_depths, train_results, 'b', label='Train AUC')
line2, = plt.plot(max_depths, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1:HandlerLine2D(numpoints=2)})

plt.ylabel('AUC score')
plt.xlabel('max depth')
plt.show()

# %%
learning_rates = [0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 1]
train_results = []
test_results = []
for learning_rate in learning_rates:
    model = GradientBoostingClassifier(learning_rate=learning_rate)
    model.fit(X, y)
    train_pred = model.predict(X_train)
    fp_rate, tp_rate, threshold = roc_curve(y_train, train_pred)
    roc_auc = auc(fp_rate, tp_rate)
    train_results.append(roc_auc)
    
    y_pred = model.predict(X_test)
    fp_rate, tp_rate, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(fp_rate, tp_rate)
    test_results.append(roc_auc)

line1, = plt.plot(learning_rates, train_results, 'b', label='Train AUC')
line2, = plt.plot(learning_rates, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1:HandlerLine2D(numpoints=2)})

plt.ylabel('AUC score')
plt.xlabel('learning rates')
plt.show()

# %%
n_estimators = [1, 2, 4, 8, 16, 32, 64, 100, 200, 300]
train_results = []
test_results = []
for est in n_estimators:
    model = GradientBoostingClassifier(n_estimators=est)
    model.fit(X, y)
    train_pred = model.predict(X_train)
    fp_rate, tp_rate, threshold = roc_curve(y_train, train_pred)
    roc_auc = auc(fp_rate, tp_rate)
    train_results.append(roc_auc)
    
    y_pred = model.predict(X_test)
    fp_rate, tp_rate, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(fp_rate, tp_rate)
    test_results.append(roc_auc)

line1, = plt.plot(n_estimators, train_results, 'b', label='Train AUC')
line2, = plt.plot(n_estimators, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1:HandlerLine2D(numpoints=2)})

plt.ylabel('AUC score')
plt.xlabel('n_estimators')
plt.show()

# %%
min_samples_splits = np.linspace(0.1, 1.0, 10, endpoint=True)
train_results = []
test_results = []
for samples in min_samples_splits:
    model = GradientBoostingClassifier(min_samples_split=samples)
    model.fit(X, y)
    train_pred = model.predict(X_train)
    fp_rate, tp_rate, threshold = roc_curve(y_train, train_pred)
    roc_auc = auc(fp_rate, tp_rate)
    train_results.append(roc_auc)
    
    y_pred = model.predict(X_test)
    fp_rate, tp_rate, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(fp_rate, tp_rate)
    test_results.append(roc_auc)

line1, = plt.plot(min_samples_splits, train_results, 'b', label='Train AUC')
line2, = plt.plot(min_samples_splits, test_results, 'r', label='Test AUC')
plt.legend(handler_map={line1:HandlerLine2D(numpoints=2)})

plt.ylabel('AUC score')
plt.xlabel('min_samples_splits')
plt.show()

# %%
gbrt = GradientBoostingClassifier(random_state=0,learning_rate=1, max_depth=2, max_features=10, n_estimators=200)
gbrt.fit(X, y)
print(gbrt.score(X_train, y_train))
print(gbrt.score(X_test, y_test))
# Out:
# 0.9922222222222222
# 0.9933333333333333

# %%
#learning_rate - уменьшает вклад каждого дерева
#max_depth - максимальная глубина дерева, хорошо контролирует переобучения
#max_features - количество признаков, которое следует учитывать при поиске лучшего разделения
#n_estimators - количество деревьев, по умолчанию 100
#random_state - управляет случайным начальным значением передаваемым каждому оценщику дерева на каждой итерации повышения

def plot_feature_importances(model):
 n_features = X.shape[1]
 plt.barh(range(n_features), model.feature_importances_, align='center')
 plt.yticks(np.arange(n_features), new_clmns)
 plt.xlabel("Важность признака")
 plt.ylabel("Признак")
plot_feature_importances(gbrt)
